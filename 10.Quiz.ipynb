# %% [markdown]
# 10. グラフ: Graph

# %%
# 学籍番号: 
# 氏名:

# %%
import networkx as nx

def define_graph():
    g = nx.DiGraph()
    edges = [('A', 'B'), ('A', 'C'), ('B', 'C'), ('B', 'E'),
            ('C', 'D'), ('C', 'E'), ('D', 'A'), ('D', 'F'), ('E', 'F'), ('F', 'C')]
    g.add_edges_from(edges)
    positions = {'A': (0, 0), 'B': (1, 1), 'C': (1, 0), 'D': (1, -1), 'E': (2, 1), 'F': (2, -1)}
    nx.set_node_attributes(g, positions, 'pos')
    return g

g = define_graph()
positions = nx.get_node_attributes(g, 'pos')
nx.draw(g, pos=positions, with_labels=True)
